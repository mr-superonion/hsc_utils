# %%
# %matplotlib inline

import numpy as np
import matplotlib.pylab as plt

from utils_shear_ana import pltutil
from utils_shear_ana import chainutil

# %%
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
outlist=[]
infname0='realspace/outputs/polychord_fid.txt'
outlist.append(chainutil.read_cosmosis_chain(infname0))
infname0='realspace/outputs/multinest_nobary.txt'
outlist.append(chainutil.read_cosmosis_chain(infname0))
cnamelist = [ 'fiducial', 'no bary']
nlist = ['omega_m', 's_8']
plt.close()
blind_by = None
fig=pltutil.plot_chain_corner(
    outlist, cnamelist, blind_by, nlist, scale = 2.3, 
    plot_hists=True, shade=True, color_use=[colors[0], colors[5]],
)
# Out:
# LOADING CHAIN FROM FILE:  realspace/outputs/polychord_fid.txt
# LOADING CHAIN FROM FILE:  realspace/outputs/multinest_nobary.txt
