# %%
# %matplotlib inline

import os
import gc
import numpy as np
from utils_shear_ana import pltutil
import matplotlib.pylab as plt

# %%
gc.collect()
plt.close()
fig,axes=pltutil.make_tpcf_plot(title='thetaxi')

blind_ver='cat0' 
fieldname='all'
fname='realspace/data_extend_all_cat0.fits'
pltutil.plot_xipm_data(fname,axes,color='blue', marker='o')
fname='realspace/outputs/fid_sim/'
pltutil.plot_xipm_model(fname,axes,color='black')
for i in range(1,5):
    axes['1%d_p' %i].set_ylim(-0.8, 2.8)
    axes['1%d_m' %i].set_ylim(-0.8, 2.8)
for i in range(2,5):
    axes['2%d_p' %i].set_ylim(1.5, 5)
    axes['2%d_m' %i].set_ylim(0.5, 5.5)
for i in range(3,5):
    axes['3%d_p' %i].set_ylim(2.2, 8.5)
    axes['3%d_m' %i].set_ylim(1.0, 8)
for i in range(4,5):
    axes['4%d_p' %i].set_ylim(3, 11)
    axes['4%d_m' %i].set_ylim(3, 9.5)
